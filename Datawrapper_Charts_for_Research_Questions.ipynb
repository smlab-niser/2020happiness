# %% [markdown]
# **Research Questions and the answers to them based on the statistical distribution charts**

# %%
How is the distribution of happiness factors made based on the 4 happiness classes?

The plot illustrates students were pleased with CE(averagely 25%) in all 4 classes; WB and COE showed a remarkable variation in 4 classes(11%).

# %% [markdown]
# ![RQ10.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# What is the female
# participation statistics
# based on university
# students survey?
#
# The plot illustrates average happiness
# score(2.82) for CE and SD(1.41) for ages 30-
# 35. Average happiness score(2.64) for RF
# and SD(1.41) for ages 25-30.

# %% [markdown]
# ![RQ8.png](data:image/png;base64,...)

# %% [markdown]
# What is the male
# participation statistics
# based on university
# students survey?
#
# The plot illustrates average happiness
# score(2.82) for CE and SD(1.41) for ages
# 30-35. Average happiness score(2.64) for RF
# and SD(2.12) for ages 25-30.

# %% [markdown]
# ![RQ7.png](data:image/png;base64,...)

# %% [markdown]
# What is the departmental statistics based
# on all happiness factors?
# The plot depicts that average happiness
# score of 3.3 was seen in Chemistry department for TM, GSR for English, COE for Zoology and WB for Personal Management.

# %% [markdown]
# ![RQ6.png](data:image/png;base64,...)

# %% [markdown]
#  How are the ’Sad’ students grouped based
# on Happiness parameters department-wise?
#
# The stacked column chart depicts Library
# and Information Science students were Sad
# about RF. Averagely, students from Chemistry and Zoology were Sad with TM and
# COE respectively

# %% [markdown]
# ![RQ5.png](data:image/png;base64,...)

# %% [markdown]
#  How are the ’Neutral’ students grouped
# based on Happiness parameters departmentwise?
#
#
# The stacked column chart depicts Pharmacy
# and Philosophy students were Neutral with
# RF and COE.

# %% [markdown]
# ![RQ4.png](data:image/png;base64,...)

# %% [markdown]
# How are the ’Happy’
# students grouped
# together based on
# Happiness parameters
# department-wise?
#
#
# The stacked column chart depicts English
# and Commerce students were Happy with
# WB and COE. Averagely, students from
# Computer Science and Applications, Political Science, Geography, and Sociology were
# Happy with WB, CE, GSR respectively.

# %% [markdown]
# ![RQ3.png](data:image/png;base64,...)

# %% [markdown]
# How are the ’Very
# Happy’ students
# grouped together
# based on Happiness parameters
# department-wise?
#
# The stacked column chart depicts Commerce students were Very Happy with TM;
# Averagely students of Women Studies, History and Archaeology, Chemistry, Sociology,
# and Public administration were Very Happy
# with UR, COE, WB and, ECA respectively.

# %% [markdown]
# ![RQ2.png](data:image/png;base64,...)

# %% [markdown]
# What is the distribution of happiness score made department wise?
#
# The happiness range plot showed an eminent distinction in Law, Odia and Physics
# department. On the contrary, Zoology and
# Chemistry had negligible scores. Average
# score turned out to be 2.51

# %% [markdown]
# ![RQ1.png](data:image/png;base64,...)

# %% [markdown]
#  What is the overall participation percentage of students based on happiness factors?
#
#  The pie chart outlines the exceptional happiness score for CE based on the overall participation of females(age 25-30) and negligible male participation. Overall percentage resulting to 17\% for RF and ECA.

# %% [markdown]
# ![RQ13.png](data:image/png;base64,...)

# %% [markdown]
# What is the distribution of happiness factors based on their SD department-wise?
#
# The plot highlights the maximum standard deviation of Happiness scores(3 and 2.6) in the Botany and Philosophy department in ECA. WB in Biotechnology and Philosophy department is also catching up(2.7 and 2.3).

# %% [markdown]
# ![RQ12.png](data:image/png;base64,...)

# %% [markdown]
# What is the percentage distribution of happiness classes based on
# happiness factors?
#
# The pie chart portrays irrespective of the department, considering all the happiness factors, averagely 46% of students were Very
# Happy and Sad while Happy and Neutral resulting in 44% and 45%. Least percent(13%)
# for Happy and Sad classes.

# %% [markdown]
# ![RQ11.png](data:image/png;base64,...)
